# %%
dict_a={10:[5,15], 5:[4,7], 15:[13, 19], 4:[0,3], 7:[6,9], 13:[11,14], 19:[17,20] }

print(dict_a)

{10: [5, 15], 5: [4, 7], 15: [13, 19], 4: [0, 3], 7: [6, 9], 13: [11, 14], 19: [17, 20]}

print('[10]')

print('[5, 15]')

print('[[4,7],[13, 19]]')

print('[[[0,3],[6,9]],[[11,14],[17, 20]]]')

​

[10]
[5, 15]
[[4,7],[13, 19]]
[[[0,3],[6,9]],[[11,14],[17, 20]]]

import math 

​

root=10

root_str=str(10).center(60, )

print(root_str)

level_1=str(dict_a[root][0])+"\t\t"+str(dict_a[root][1])

level_1_center=level_1.center(50, )

print(level_1_center)

level_2=str(dict_a[dict_a[root][0]][0])\

+"\t"\

+str(dict_a[dict_a[root][0]][1])\

+"\t"\

+str(dict_a[dict_a[root][1]][0])\

+"\t"\

+str(dict_a[dict_a[root][1]][1])

​

​

level_2_center=level_2.center(40, )

print(level_2_center)

​

                             10                             
                      5		15                       
               4	7	13	19                

print("       _________10________")

print("      |                   |")

print("   ___5___           ____15___")

print("  |       |         |         | ")

print(" _4_     _7_      _13_      _19_")

print("|   |   |   |    |    |    |    |")

print("0   3   6   9   11   14   17   20")

       _________10________
      |                   |
   ___5___           ____15___
  |       |         |         | 
 _4_     _7_      _13_      _19_
|   |   |   |    |    |    |    |
0   3   6   9   11   14   17   20

print(" \t \t \t20")

print(" \t \t19---|")

print(" \t \t \t17")

print(" \t15---|")

print(" \t \t \t14")

print(" \t \t13---|")

print(" \t \t \t11")

print("10---|")

print(" \t \t \t09")

print(" \t \t07---|")

print(" \t \t \t06")

print(" \t05---|")

print(" \t \t \t03")

print(" \t \t04---|")

print(" \t \t \t00")

​

 	 	 	20
 	 	19---|
 	 	 	17
 	15---|
 	 	 	14
 	 	13---|
 	 	 	11
10---|
 	 	 	09
 	 	07---|
 	 	 	06
 	05---|
 	 	 	03
 	 	04---|
 	 	 	00
